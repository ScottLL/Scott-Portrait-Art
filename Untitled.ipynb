# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.pyplot import figure, draw
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 
import matplotlib.animation as animation
from pathlib import Path
import matplotlib as cm

# %%
A = pd.read_csv('/Users/scottlai/Desktop/work/3D/data/3d.csv')
A.head()
# Out:
#    x  y  w    z  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0  0  1  1  1/2         NaN         NaN         NaN         NaN
# 1  1  1  2    1         NaN         NaN         NaN         NaN
# 2  2  1  3  1/2         NaN         NaN         NaN         NaN
# 3  3  1  4    2         NaN         NaN         NaN         NaN
# 4  4  1  5  1/2         NaN         NaN         NaN         NaN

# %%
N = 150 # Meshsize
fps = 10 # frame per sec
frn = 50 # frame number of the animation

x = np.linspace(-4,4,N+1)
x, y = np.meshgrid(x, x)
zarray = np.zeros((N+1, N+1, frn))

f = lambda x,y,sig : 1/np.sqrt(sig)*np.exp(-(x**2+y**2)/sig**2)

for i in range(frn):
    zarray[:,:,i] = f(x,y,1.5+np.sin(i*2*np.pi/frn))

    
    
def update_plot(frame_number, zarray, plot):
    plot[0].remove()
    plot[0] = ax.plot_surface(x, y, zarray[:,:,frame_number], cmap="magma")

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plot = [ax.plot_surface(x, y, zarray[:,:,0], color='0.75', rstride=1, cstride=1)]
ax.set_zlim(0,1.1)
ani = animation.FuncAnimation(fig, update_plot, frn, fargs=(zarray, plot), interval=1000/fps)

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
for c, z in zip(['r', 'g', 'b', 'y'], [30, 20, 10, 0]):
    xs = np.arange(20)
    ys = np.random.rand(20)

    # You can provide either a single color or an array. To demonstrate this,
    # the first bar of each set will be colored cyan.
    cs = [c] * len(xs)
    cs[0] = 'c'
    ax.bar(xs, ys, zs=z, zdir='y', color=cs, alpha=0.8)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import visvis as vv

fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')

fn = Path('/Users/scottlai/Desktop/work/3D/code/mycoolfig.svg').expanduser()





ax1.set_xlim3d(0, 200)
ax1.set_ylim3d(0,200)
ax1.set_zlim3d(0,10)


xpos = A['x']
ypos = A['y']
num_elements = len(xpos)
A['zpos'] = 0
zpos = A['zpos']
dx = np.ones(num_elements)
dy = np.ones(num_elements)
dz = pd.to_numeric(A['z'],errors='coerce')

ax1.bar3d(xpos, ypos, zpos, dx, dy, dz, cmap="viridis")

plt.show()
draw()
fig.savefig(fn, bbox_inches='tight')



app = vv.use()
app.Run()
# Out:
# /Users/scottlai/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py:1765: RuntimeWarning: divide by zero encountered in true_divide
#   shade = ((normals / np.linalg.norm(normals, axis=1, keepdims=True))
